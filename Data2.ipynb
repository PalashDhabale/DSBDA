# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.hist(column="sepal_length")
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>]], dtype=object)

# %%
df.hist(column="sepal_width")
# Out:
# array([[<AxesSubplot:title={'center':'sepal_width'}>]], dtype=object)

# %%
df.hist(column="petal_length")
# Out:
# array([[<AxesSubplot:title={'center':'petal_length'}>]], dtype=object)

# %%
df.hist(column="petal_width")
# Out:
# array([[<AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
plt.boxplot(df[["sepal_width","petal_width","sepal_length","petal_length"]])
# Set labels for x-axis and y-axis
plt.xticks([1, 2, 3, 4], ['sepal_width', 'petal_width', 'sepal_length', 'petal_length'])
plt.ylabel('Measurement')

# Show the plot
plt.show()
